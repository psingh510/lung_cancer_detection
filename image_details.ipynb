# %%
import cv2

# Load the image
image = cv2.imread('E:\MLOps\Project\Images from Dellaire Lab\TIFF SAEC rep1 63x As high\C0\SAEC exp1 As High 63x - Position 1_Z00_C0.tif')

# Get the shape of the image
height, width, channels = image.shape

# Print the number of channels
print(f'Number of channels: {channels}')
# Out:
# Number of channels: 3

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

image_pil = Image.open('E:\MLOps\Project\Images from Dellaire Lab\TIFF SAEC rep1 63x As high\C0\SAEC exp1 As High 63x - Position 1_Z00_C0.tif')
image_pil2 = Image.open('E:\MLOps\Project\Images from Dellaire Lab\TIFF SAEC rep1 63x As high\C1\SAEC exp1 As High 63x - Position 1_Z00_C1.tif')

print("Mode of nucleus Image: ", image_pil.mode) 
print("Mode of pml bodies Image: ", image_pil2.mode) 

image_array1 = np.array(image_pil)
image_array2 = np.array(image_pil2)
print("Shape of the nucleus image: ", image_array1.shape)
print("Shape of the pml bodies image: ", image_array1.shape)

plt.imshow(image_pil)
plt.show()
plt.imshow(image_pil2)
plt.show()
# Out:
# Mode of nucleus Image:  I;16
# Mode of pml bodies Image:  I;16
# Shape of the nucleus image:  (512, 512)
# Shape of the pml bodies image:  (512, 512)
