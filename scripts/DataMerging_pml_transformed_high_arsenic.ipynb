# %%
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import os
import numpy as np
import cv2 as cv
import re

# %%
def extract_position(input_name):
    # Use regex to find the 'Position' part
    match = re.search(r'Position \d+ - \d+_Z\d+_C\d+', input_name)
    if match:
        return match.group(0)
    else:
        return "Unknown_Position"

# %%
folder1 = 'E:\MLOps\Project\Images from Dellaire Lab\Dataset part 1\TIFF SAEC rep1 63x As high\C1'

# %%
folder2 = 'E:\MLOps\Project\Images from Dellaire Lab\Dataset part 2\TIFF SAEC rep1 63x As high\C1'

# %%
folder3 = 'E:\MLOps\Project\Images from Dellaire Lab\TIFF SAEC rep1 63x As high\merged-pml-high-arsenic'

# %%
output_folder1 = 'E:/MLOps/Project/Images from Dellaire Lab/TIFF SAEC rep1 63x As high/merged-pml-part1'

# %%
output_folder2 = 'E:/MLOps/Project/Images from Dellaire Lab/TIFF SAEC rep1 63x As high/merged-pml-part2'

# %%
output = 'E:/MLOps/Project/Images from Dellaire Lab/TIFF SAEC rep1 63x As high/transformed-merged'

# %%
import os
import re
import cv2 as cv
import numpy as np
from pathlib import Path

def extract_z_info(filename):
    """Extract position and Z-stack information from filename."""
    # Match pattern like "Position 1 - 1_Z00_C1" or "Position 1_Z01_C1"
    match = re.search(r'Position (\d+(?:\s*-\s*\d+)?)[_ ](Z\d+)_(C\d+)', filename)
    
    if match:
        position = match.group(1).replace(' ', '')  # Remove spaces from position
        z_number = int(match.group(2)[1:])  # Extract number from Z00, Z01, etc.
        channel = match.group(3)
        return position, z_number, channel
    else:
        return None, None, None

def flatten_z_stacks(input_folder, output_folder):
    """
    Create flattened 2D images by combining all Z-projections for each position.
    """
    # Create output folder if it doesn't exist
    Path(output_folder).mkdir(parents=True, exist_ok=True)
    
    # Get all .tif and .jpg files
    all_files = [f for f in os.listdir(input_folder) if f.endswith(('.tif', '.jpg'))]
    print(f"\nTotal image files found: {len(all_files)}")
    
    if not all_files:
        raise ValueError(f"No image files found in {input_folder}")
    
    # Group files by position and channel
    position_stacks = {}
    for filename in all_files:
        position, z_number, channel = extract_z_info(filename)
        if position is not None:
            key = (position, channel)
            if key not in position_stacks:
                position_stacks[key] = []
            position_stacks[key].append((z_number, filename))
    
    # Print found positions and channels
    print(f"\nFound {len(position_stacks)} position-channel combinations:")
    for (pos, channel), files in position_stacks.items():
        print(f"Position {pos}, {channel}: {len(files)} Z-stacks")
    
    # Process each position-channel combination
    for (position, channel), files in position_stacks.items():
        print(f"\nProcessing Position {position}, {channel}")
        
        # Sort files by Z number
        files.sort()  # Will sort based on Z-number
        
        # Initialize variables for stack processing
        stack = []
        first_image = True
        
        # Process each Z-stack
        for z_number, filename in files:
            img_path = os.path.join(input_folder, filename)
            print(f"  Reading Z-stack {z_number}: {filename}")
            
            if os.path.exists(img_path):
                # Read image in original bit depth
                if filename.endswith('.tif'):
                    image = cv.imread(img_path, cv.IMREAD_GRAYSCALE)
                else:  # .jpg file
                    image = cv.imread(img_path, cv.IMREAD_GRAYSCALE)
                
                if image is not None:
                    if first_image:
                        # Initialize image properties from first image
                        img_height, img_width = image.shape[:2]
                        first_image = False
                        
                    # Convert to float32 for processing
                    image = image.astype(np.float32)
                    
                    # Add to stack
                    stack.append(image)
                    print(f"    Successfully added to stack")
                else:
                    print(f"    Warning: Could not read image")
            else:
                print(f"    Warning: File not found")
        
        if stack:
            # Convert stack to numpy array
            stack = np.array(stack)
            print(f"  Processing stack of shape: {stack.shape}")
            
            # Create maximum intensity projection
            flattened = np.max(stack, axis=0)
            
            # Normalize the image
            flattened_min = np.min(flattened)
            flattened_max = np.max(flattened)
            if flattened_max > flattened_min:
                flattened = ((flattened - flattened_min) * 
                           (255.0 / (flattened_max - flattened_min)))
            
            # Convert to uint8
            flattened = flattened.astype(np.uint8)
            
            # Apply CLAHE for contrast enhancement
            clahe = cv.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
            enhanced = clahe.apply(flattened)
            
            # Save both versions
            base_output = f"ha_flattened_position_{position}_{channel}"
            
            # Save original flattened image as .tif
            output_path = os.path.join(output_folder, f"{base_output}.tif")
            cv.imwrite(output_path, flattened)
            print(f"Saved flattened image: {output_path}")
            
            
        else:
            print(f"Warning: No valid images found for Position {position}, {channel}")

# Example usage
if __name__ == "__main__":
    input_folder = folder1  # Replace with your input folder path
    output_folder = output_folder  # Replace with your output folder path
    
    try:
        flatten_z_stacks(input_folder, output_folder)
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# Total image files found: 1481
#
# Found 40 position-channel combinations:
# Position 10, C1: 37 Z-stacks
# Position 11, C1: 37 Z-stacks
# Position 12, C1: 37 Z-stacks
# Position 13, C1: 37 Z-stacks
# Position 14, C1: 37 Z-stacks
# Position 15, C1: 37 Z-stacks
# Position 16, C1: 37 Z-stacks
# Position 17, C1: 37 Z-stacks
# Position 18, C1: 37 Z-stacks
# Position 19, C1: 37 Z-stacks
# Position 1, C1: 37 Z-stacks
# Position 20, C1: 37 Z-stacks
# Position 21, C1: 37 Z-stacks
# Position 22, C1: 37 Z-stacks
# Position 23, C1: 37 Z-stacks
# Position 24, C1: 37 Z-stacks
# Position 25, C1: 37 Z-stacks
# Position 26, C1: 37 Z-stacks
# Position 27, C1: 37 Z-stacks
# Position 28, C1: 37 Z-stacks
# Position 29, C1: 37 Z-stacks
# Position 2, C1: 37 Z-stacks
# Position 30, C1: 37 Z-stacks
# Position 31, C1: 37 Z-stacks
# Position 32, C1: 37 Z-stacks
# Position 33, C1: 37 Z-stacks
# Position 34, C1: 37 Z-stacks
# Position 35, C1: 37 Z-stacks
# Position 36, C1: 37 Z-stacks
# Position 37, C1: 37 Z-stacks
# Position 38, C1: 37 Z-stacks
# Position 39, C1: 37 Z-stacks
# Position 3, C1: 37 Z-stacks
# Position 40, C1: 37 Z-stacks
# Position 4, C1: 37 Z-stacks
# Position 5, C1: 37 Z-stacks
# Position 6, C1: 37 Z-stacks
# Position 7, C1: 37 Z-stacks
# Position 8, C1: 37 Z-stacks
# Position 9, C1: 37 Z-stacks
#
# Processing Position 10, C1
#   Reading Z-stack 0: transformed_pml - Position 10_Z00_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 1: transformed_pml - Position 10_Z01_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 2: transformed_pml - Position 10_Z02_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 3: transformed_pml - Position 10_Z03_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 4: transformed_pml - Position 10_Z04_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 5: transformed_pml - Position 10_Z05_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 6: transformed_pml - Position 10_Z06_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 7: transformed_pml - Position 10_Z07_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 8: transformed_pml - Position 10_Z08_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 9: transformed_pml - Position 10_Z09_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 10: transformed_pml - Position 10_Z10_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 11: transformed_pml - Position
Z12_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 13: transformed_pml - Position 8_Z13_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 14: transformed_pml - Position 8_Z14_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 15: transformed_pml - Position 8_Z15_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 16: transformed_pml - Position 8_Z16_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 17: transformed_pml - Position 8_Z17_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 18: transformed_pml - Position 8_Z18_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 19: transformed_pml - Position 8_Z19_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 20: transformed_pml - Position 8_Z20_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 21: transformed_pml - Position 8_Z21_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 22: transformed_pml - Position 8_Z22_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 23: transformed_pml - Position 8_Z23_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 24: transformed_pml - Position 8_Z24_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 25: transformed_pml - Position 8_Z25_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 26: transformed_pml - Position 8_Z26_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 27: transformed_pml - Position 8_Z27_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 28: transformed_pml - Position 8_Z28_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 29: transformed_pml - Position 8_Z29_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 30: transformed_pml - Position 8_Z30_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 31: transformed_pml - Position 8_Z31_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 32: transformed_pml - Position 8_Z32_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 33: transformed_pml - Position 8_Z33_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 34: transformed_pml - Position 8_Z34_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 35: transformed_pml - Position 8_Z35_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 36: transformed_pml - Position 8_Z36_C1.jpg
#     Successfully added to stack
#   Processing stack of shape: (37, 512, 512)
# Saved flattened image: E:/MLOps/Project/Images from Dellaire Lab/TIFF SAEC rep1 63x As high/transformed-merged\flattened_position_8_C1.tif
# Saved enhanced version: E:/MLOps/Project/Images from Dellaire Lab/TIFF SAEC rep1 63x As high/transformed-merged\flattened_position_8_C1_enhanced.tif
# Saved depth map: E:/MLOps/Project/Images from Dellaire Lab/TIFF SAEC rep1 63x As high/transformed-merged\flattened_position_8_C1_depth_map.tif
#
# Processing Position 9, C1
#   Reading Z-stack 0: transformed_pml - Position 9_Z00_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 1: transformed_pml - Position 9_Z01_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 2: transformed_pml - Position 9_Z02_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 3: transformed_pml - Position 9_Z03_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 4: transformed_pml - Position 9_Z04_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 5: transformed_pml - Position 9_Z05_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 6: transformed_pml - Position 9_Z06_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 7: transformed_pml - Position 9_Z07_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 8: transformed_pml - Position 9_Z08_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 9: transformed_pml - Position 9_Z09_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 10: transformed_pml - Position 9_Z10_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 11: transformed_pml - Position 9_Z11_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 12: transformed_pml - Position 9_Z12_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 13: transformed_pml - Position 9_Z13_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 14: transformed_pml - Position 9_Z14_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 15: transformed_pml - Position 9_Z15_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 16: transformed_pml - Position 9_Z16_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 17: transformed_pml - Position 9_Z17_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 18: transformed_pml - Position 9_Z18_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 19: transformed_pml - Position 9_Z19_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 20: transformed_pml - Position 9_Z20_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 21: transformed_pml - Position 9_Z21_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 22: transformed_pml - Position 9_Z22_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 23: transformed_pml - Position 9_Z23_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 24: transformed_pml - Position 9_Z24_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 25: transformed_pml - Position 9_Z25_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 26: transformed_pml - Position 9_Z26_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 27: transformed_pml - Position 9_Z27_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 28: transformed_pml - Position 9_Z28_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 29: transformed_pml - Position 9_Z29_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 30: transformed_pml - Position 9_Z30_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 31: transformed_pml - Position 9_Z31_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 32: transformed_pml - Position 9_Z32_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 33: transformed_pml - Position 9_Z33_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 34: transformed_pml - Position 9_Z34_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 35: transformed_pml - Position 9_Z35_C1.jpg
#     Successfully added to stack
#   Reading Z-stack 36: transformed_pml - Position 9_Z36_C1.jpg
#     Successfully added to stack
#   Processing stack of shape: (37, 512, 512)
# Saved flattened image: E:/MLOps/Project/Images from Dellaire Lab/TIFF SAEC rep1 63x As high/transformed-merged\flattened_position_9_C1.tif
# Saved enhanced version: E:/MLOps/Project/Images from Dellaire Lab/TIFF SAEC rep1 63x As high/transformed-merged\flattened_position_9_C1_enhanced.tif
# Saved depth map: E:/MLOps/Project/Images from Dellaire Lab/TIFF SAEC rep1 63x As high/transformed-merged\flattened_position_9_C1_depth_map.tif

# %%
# Loop through all files in the folder
for filename in os.listdir(folder3):
    if filename.endswith('.tif'):
        # Load the image
        image = cv.imread(os.path.join(folder3, filename))

        # Perform linear transformation
        new_image = np.zeros(image.shape, image.dtype)
        alpha = 3.5
        beta = 0
        for y in range(image.shape[0]):
            for x in range(image.shape[1]):
                for c in range(image.shape[2]):
                    new_image[y,x,c] = np.clip(alpha*image[y,x,c] + beta, 0, 255)

        # Convert to grayscale and create a mask for white dots
        threshold = 70
        gray_image = cv.cvtColor(new_image, cv.COLOR_BGR2GRAY)
        mask = gray_image > threshold

        # Highlight white dots in the image
        new_image[mask] = [0, 255, 0]  # BGR for green

        # Save the modified image
        cv.imwrite(os.path.join(output, '' + filename), new_image)
