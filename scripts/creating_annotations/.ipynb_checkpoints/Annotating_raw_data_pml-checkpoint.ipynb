# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import json
from datetime import datetime

# %%
def process_single_image(image_path, mask_path):
    """Process a single image using the original logic, but also consider a mask."""
    # Read the image with unchanged flag
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    if image is None:
        return None, None, 0
    
    # Convert to 3-channel if it's single channel
    if len(image.shape) == 2:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
    
    # Read the mask image
    mask = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)
    
    # Create a new image
    new_image = np.zeros(image.shape, image.dtype)
    alpha = 3.5
    beta = 0
    
    for y in range(image.shape[0]):
        for x in range(image.shape[1]):
            for c in range(image.shape[2]):
                new_image[y,x,c] = np.clip(alpha*image[y,x,c] + beta, 0, 255)
                
    gray_image = cv2.cvtColor(new_image, cv2.COLOR_BGR2GRAY)
    # threshold for arsenic
    threshold = 70
     
    mask = gray_image > threshold
    new_image[mask] = [0, 255, 0]  # Set to green
    
    # Convert to RGB for processing
    image_rgb = cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB)
    hsv_image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)
    
    # Define range for green color in HSV
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])
    green_mask = cv2.inRange(hsv_image, lower_green, upper_green)
    
    # Find contours, but only outside the mask
    contours, _ = cv2.findContours(green_mask & ~cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Draw bounding squares on the original RGB image
    annotated_image = image_rgb.copy()
    
    dot_info = []
    for i, contour in enumerate(contours):
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(annotated_image, (x, y), (x + w, y + h), (255, 255, 0), 2)
        
        dot_info.append({
            'dot_id': i + 1,
            'position': {'x': int(x + w/2), 'y': int(y + h/2)},
            'width': w,
            'height': h,
            'area': int(cv2.contourArea(contour))
        })
    
    # Convert back to BGR for saving
    annotated_image_bgr = cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR)
    
    return annotated_image_bgr, dot_info, len(contours)

# %%
def process_folder(input_folder, output_folder, json_output_path, label, nucleus_mask_folder):
    """Process all images in a folder and save results."""
    os.makedirs(output_folder, exist_ok=True)
    
#     results = {
#         'processing_date': datetime.now().isoformat(),
#         'total_images_processed': 0,
#         'images': {}
#     }
    
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.tif', '.tiff')):
            image_path = os.path.join(input_folder, filename)
            print(f"Processing {filename}...")
            
            try:
                annotated_image, dot_info, dot_count = process_single_image(image_path)
                
                if annotated_image is None:
                    print(f"Failed to process {filename}")
                    continue
                
                # Get the nucleus mask file path
                mask_filename = f"{os.path.splitext(filename)[0]}_mask.tiff"
                nucleus_mask_path = os.path.join(nucleus_mask_folder, mask_filename)
                
                # Build JSON format for the image
                image_data = {
                    "image_name": os.path.splitext(filename)[0],
                    "label": label,
                    "nucleus_mask": nucleus_mask_path,
                    "dots": dot_info
                }
                
                # Save the annotated image as TIFF with maximum quality
                output_filename = os.path.join(output_folder, f"annotated_{filename}")
                # Save with original bit depth and compression
                cv2.imwrite(output_filename, 
                          annotated_image,
                          [cv2.IMWRITE_TIFF_COMPRESSION, 1])  # Use LZW compression for better quality
                
#                 results['images'][filename] = {
#                     'filename': filename,
#                     'annotated_filename': f"annotated_{filename}",
#                     'dot_count': dot_count,
#                     'dots': dot_info
#                 }
                
#                 results['total_images_processed'] += 1
                results.append(image_data)
    
            except Exception as e:
                print(f"Error processing {filename}: {str(e)}")
                continue
    
    with open(json_output_path, 'w') as f:
        json.dump(results, f, indent=4)
    
    return results

# %%
# Example usage:
input_folder = '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/Nuclei and pml training image data/merged-pml-no-arsenic'
output_folder = '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/misc/merged-pml-images-No-arsenic-annotations'
json_output_path = '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/annotations/non_arsenic_updated.json'
label = "not arsenic"  # Example label, change as needed
nucleus_mask_folder = ""

process_folder(input_folder, output_folder, json_output_path, label, nucleus_mask_folder)
# Out:
# Processing flattened_position_40-1_C1.tif...
# Error processing flattened_position_40-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_37-1_C1.tif...
# Error processing flattened_position_37-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_36-1_C1.tif...
# Error processing flattened_position_36-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_10_C1.tif...
# Error processing flattened_position_10_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_6_C1.tif...
# Error processing flattened_position_6_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_34_C1.tif...
# Error processing flattened_position_34_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_26_C1.tif...
# Error processing flattened_position_26_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_38_C1.tif...
# Error processing flattened_position_38_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_4_C1.tif...
# Error processing flattened_position_4_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_6-1_C1.tif...
# Error processing flattened_position_6-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_7-1_C1.tif...
# Error processing flattened_position_7-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_8_C1.tif...
# Error processing flattened_position_8_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_12_C1.tif...
# Error processing flattened_position_12_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_24_C1.tif...
# Error processing flattened_position_24_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_20-1_C1.tif...
# Error processing flattened_position_20-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_21-1_C1.tif...
# Error processing flattened_position_21-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_28_C1.tif...
# Error processing flattened_position_28_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_36_C1.tif...
# Error processing flattened_position_36_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_14-1_C1.tif...
# Error processing flattened_position_14-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_15-1_C1.tif...
# Error processing flattened_position_15-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_32_C1.tif...
# Error processing flattened_position_32_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_1-1_C1.tif...
# Error processing flattened_position_1-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_20_C1.tif...
# Error processing flattened_position_20_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_19-1_C1.tif...
# Error processing flattened_position_19-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_18-1_C1.tif...
# Error processing flattened_position_18-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_16_C1.tif...
# Error processing flattened_position_16_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_27-1_C1.tif...
# Error processing flattened_position_27-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_26-1_C1.tif...
# Error processing flattened_position_26-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_13-1_C1.tif...
# Error processing flattened_position_13-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_12-1_C1.tif...
# Error processing flattened_position_12-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_30-1_C1.tif...
# Error processing flattened_position_30-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_31-1_C1.tif...
# Error processing flattened_position_31-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_22_C1.tif...
# Error processing flattened_position_22_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_30_C1.tif...
# Error processing flattened_position_30_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_2_C1.tif...
# Error processing flattened_position_2_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_18_C1.tif...
# Error processing flattened_position_18_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_14_C1.tif...
# Error processing flattened_position_14_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_35_C1.tif...
# Error processing flattened_position_35_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_17-1_C1.tif...
# Error processing flattened_position_17-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_16-1_C1.tif...
# Error processing flattened_position_16-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_39_C1.tif...
# Error processing flattened_position_39_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_27_C1.tif...
# Error processing flattened_position_27_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_29-1_C1.tif...
# Error processing flattened_position_29-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_28-1_C1.tif...
# Error processing flattened_position_28-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_11_C1.tif...
# Error processing flattened_position_11_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_7_C1.tif...
# Error processing flattened_position_7_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_5-1_C1.tif...
# Error processing flattened_position_5-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_4-1_C1.tif...
# Error processing flattened_position_4-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_23-1_C1.tif...
# Error processing flattened_position_23-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_22-1_C1.tif...
# Error processing flattened_position_22-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_25_C1.tif...
# Error processing flattened_position_25_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_37_C1.tif...
# Error processing flattened_position_37_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_29_C1.tif...
# Error processing flattened_position_29_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_5_C1.tif...
# Error processing flattened_position_5_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_34-1_C1.tif...
# Error processing flattened_position_34-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_35-1_C1.tif...
# Error processing flattened_position_35-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_9_C1.tif...
# Error processing flattened_position_9_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_13_C1.tif...
# Error processing flattened_position_13_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_39-1_C1.tif...
# Error processing flattened_position_39-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_38-1_C1.tif...
# Error processing flattened_position_38-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_17_C1.tif...
# Error processing flattened_position_17_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_1_C1.tif...
# Error processing flattened_position_1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_33_C1.tif...
# Error processing flattened_position_33_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_33-1_C1.tif...
# Error processing flattened_position_33-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_32-1_C1.tif...
# Error processing flattened_position_32-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_21_C1.tif...
# Error processing flattened_position_21_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_3_C1.tif...
# Error processing flattened_position_3_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_10-1_C1.tif...
# Error processing flattened_position_10-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_19_C1.tif...
# Error processing flattened_position_19_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_11-1_C1.tif...
# Error processing flattened_position_11-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_8-1_C1.tif...
# Error processing flattened_position_8-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_9-1_C1.tif...
# Error processing flattened_position_9-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_15_C1.tif...
# Error processing flattened_position_15_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_40_C1.tif...
# Error processing flattened_position_40_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_23_C1.tif...
# Error processing flattened_position_23_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_31_C1.tif...
# Error processing flattened_position_31_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_2-1_C1.tif...
# Error processing flattened_position_2-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_3-1_C1.tif...
# Error processing flattened_position_3-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_24-1_C1.tif...
# Error processing flattened_position_24-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# Processing flattened_position_25-1_C1.tif...
# Error processing flattened_position_25-1_C1.tif: process_single_image() missing 1 required positional argument: 'mask_path'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 8
#       5 label = "not arsenic"  # Example label, change as needed
#       6 nucleus_mask_folder = "/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/annotations/non_arsenic_updated.json"
# ----> 8 process_folder(input_folder, output_folder, json_output_path, label, nucleus_mask_folder)
#
# Cell In[5], line 56, in process_folder(input_folder, output_folder, json_output_path, label, nucleus_mask_folder)
#      53             print(f"Error processing {filename}: {str(e)}")
#      54             continue
# ---> 56 with open(json_output_path, 'w') as f:
#      57     json.dump(results, f, indent=4)
#      59 return results
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/merged-pml-images-No-arsenic-annotations/merged-pml-images-No-arsenic-annotations.json'

# %%
# Example usage for arsenic:
input_folder = '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/merged_pml_images_High_Arsenic'
output_folder = '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/merged_pml_images_High_Arsenic_annotations'
json_output_path = '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/merged_pml_images_High_Arsenic_annotations/merged_pml_images_High_Arsenic_annotations.json '
label = "arsenic"  # Example label, change as needed
nucleus_mask_folder = "/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic"

process_folder(input_folder, output_folder, json_output_path, label, nucleus_mask_folder)
# Out:
# Processing flattened_position_10_C1.tif...
# Processing flattened_position_6_C1.tif...
# Processing flattened_position_34_C1.tif...
# Processing flattened_position_26_C1.tif...
# Processing flattened_position_38_C1.tif...
# Processing flattened_position_4_C1.tif...
# Processing flattened_position_8_C1.tif...
# Processing flattened_position_12_C1.tif...
# Processing flattened_position_24_C1.tif...
# Processing flattened_position_28_C1.tif...
# Processing flattened_position_36_C1.tif...
# Processing flattened_position_32_C1.tif...
# Processing flattened_position_20_C1.tif...
# Processing flattened_position_16_C1.tif...
# Processing flattened_position_22_C1.tif...
# Processing flattened_position_30_C1.tif...
# Processing flattened_position_2_C1.tif...
# Processing flattened_position_18_C1.tif...
# Processing flattened_position_14_C1.tif...
# Processing flattened_position_35_C1.tif...
# Processing flattened_position_39_C1.tif...
# Processing flattened_position_27_C1.tif...
# Processing flattened_position_11_C1.tif...
# Processing flattened_position_7_C1.tif...
# Processing flattened_position_25_C1.tif...
# Processing flattened_position_37_C1.tif...
# Processing flattened_position_29_C1.tif...
# Processing flattened_position_5_C1.tif...
# Processing flattened_position_9_C1.tif...
# Processing flattened_position_13_C1.tif...
# Processing flattened_position_17_C1.tif...
# Processing flattened_position_1_C1.tif...
# Processing flattened_position_33_C1.tif...
# Processing flattened_position_21_C1.tif...
# Processing flattened_position_3_C1.tif...
# Processing flattened_position_19_C1.tif...
# Processing flattened_position_15_C1.tif...
# Processing flattened_position_40_C1.tif...
# Processing flattened_position_23_C1.tif...
# Processing flattened_position_31_C1.tif...
# [{'image_name': 'flattened_position_10_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_10_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 111, 'y': 470},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 2,
#     'position': {'x': 257, 'y': 464},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 3,
#     'position': {'x': 81, 'y': 462},
#     'width': 5,
#     'height': 4,
#     'area': 8},
#    {'dot_id': 4,
#     'position': {'x': 264, 'y': 455},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 5,
#     'position': {'x': 254, 'y': 453},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 6,
#     'position': {'x': 95, 'y': 443},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 7,
#     'position': {'x': 251, 'y': 439},
#     'width': 5,
#     'height': 5,
#     'area': 14},
#    {'dot_id': 8,
#     'position': {'x': 226, 'y': 350},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 9,
#     'position': {'x': 415, 'y': 344},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 10,
#     'position': {'x': 230, 'y': 344},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 11,
#     'position': {'x': 185, 'y': 339},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 12,
#     'position': {'x': 167, 'y': 335},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 13,
#     'position': {'x': 396, 'y': 332},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 14,
#     'position': {'x': 155, 'y': 332},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 15,
#     'position': {'x': 154, 'y': 329},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 16,
#     'position': {'x': 389, 'y': 323},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 17,
#     'position': {'x': 157, 'y': 318},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 18,
#     'position': {'x': 160, 'y': 316},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 19,
#     'position': {'x': 381, 'y': 310},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 20,
#     'position': {'x': 191, 'y': 308},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 21,
#     'position': {'x': 179, 'y': 307},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 22,
#     'position': {'x': 212, 'y': 238},
#     'width': 4,
#     'height': 4,
#     'area': 8},
#    {'dot_id': 23,
#     'position': {'x': 195, 'y': 228},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 24,
#     'position': {'x': 199, 'y': 206},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 25,
#     'position': {'x': 170, 'y': 199},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 26,
#     'position': {'x': 178, 'y': 178},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 27,
#     'position': {'x': 148, 'y': 165},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 28,
#     'position': {'x': 230, 'y': 163},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 29,
#     'position': {'x': 179, 'y': 164},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 30,
#     'position': {'x': 178, 'y': 157},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 31,
#     'position': {'x': 485, 'y': 156},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 32,
#     'position': {'x': 226, 'y': 151},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 33,
#     'position': {'x': 490, 'y': 102},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 34,
#     'position': {'x': 314, 'y': 97},
#     'width': 5,
#     'height': 4,
#     'area': 10},
#    {'dot_id': 35,
#     'position': {'x': 309, 'y': 95},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 36,
#     'position': {'x': 334, 'y': 94},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 37,
#     'position': {'x': 339, 'y': 87},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 38,
#     'position': {'x': 304, 'y': 84},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 39,
#     'position': {'x': 291, 'y': 58},
#     'width': 2,
#     'height': 2,
#     'area': 0}]},
#  {'image_name': 'flattened_position_6_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_6_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 362, 'y': 511},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 2,
#     'position': {'x': 387, 'y': 509},
#     'width': 6,
#     'height': 5,
#     'area': 13},
#    {'dot_id': 3,
#     'position': {'x': 390, 'y': 500},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 4,
#     'position': {'x': 362, 'y': 491},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 5,
#     'position': {'x': 306, 'y': 468},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 6,
#     'position': {'x': 314, 'y': 464},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 7,
#     'position': {'x': 328, 'y': 454},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 8,
#     'position': {'x': 353, 'y': 387},
#     'width': 8,
#     'height': 5,
#     'area': 16},
#    {'dot_id': 9,
#     'position': {'x': 179, 'y': 327},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 10,
#     'position': {'x': 381, 'y': 295},
#     'width': 7,
#     'height': 8,
#     'area': 34},
#    {'dot_id': 11,
#     'position': {'x': 371, 'y': 287},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 12,
#     'position': {'x': 362, 'y': 285},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 13,
#     'position': {'x': 375, 'y': 276},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 14,
#     'position': {'x': 362, 'y': 266},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 15,
#     'position': {'x': 354, 'y': 259},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 16,
#     'position': {'x': 334, 'y': 260},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 17,
#     'position': {'x': 67, 'y': 256},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 18,
#     'position': {'x': 387, 'y': 256},
#     'width': 3,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 19,
#     'position': {'x': 374, 'y': 238},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 20,
#     'position': {'x': 102, 'y': 226},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 21,
#     'position': {'x': 111, 'y': 226},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 22,
#     'position': {'x': 77, 'y': 224},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 23,
#     'position': {'x': 90, 'y': 215},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 24,
#     'position': {'x': 118, 'y': 213},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 25,
#     'position': {'x': 469, 'y': 145},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 26,
#     'position': {'x': 304, 'y': 122},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 27,
#     'position': {'x': 311, 'y': 115},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 28,
#     'position': {'x': 444, 'y': 97},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 29,
#     'position': {'x': 402, 'y': 86},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 30,
#     'position': {'x': 471, 'y': 82},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 31,
#     'position': {'x': 436, 'y': 77},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 32,
#     'position': {'x': 423, 'y': 73},
#     'width': 3,
#     'height': 2,
#     'area': 2}]},
#  {'image_name': 'flattened_position_34_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_34_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 112, 'y': 432},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 2,
#     'position': {'x': 89, 'y': 422},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 3,
#     'position': {'x': 105, 'y': 417},
#     'width': 4,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 4,
#     'position': {'x': 109, 'y': 410},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 5,
#     'position': {'x': 114, 'y': 407},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 6,
#     'position': {'x': 91, 'y': 409},
#     'width': 3,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 7,
#     'position': {'x': 85, 'y': 407},
#     'width': 3,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 8,
#     'position': {'x': 124, 'y': 400},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 9,
#     'position': {'x': 87, 'y': 396},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 10,
#     'position': {'x': 88, 'y': 391},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 11,
#     'position': {'x': 208, 'y': 384},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 12,
#     'position': {'x': 114, 'y': 383},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 13,
#     'position': {'x': 194, 'y': 381},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 14,
#     'position': {'x': 90, 'y': 379},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 15,
#     'position': {'x': 192, 'y': 375},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 16,
#     'position': {'x': 211, 'y': 367},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 17,
#     'position': {'x': 201, 'y': 360},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 18,
#     'position': {'x': 320, 'y': 350},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 19,
#     'position': {'x': 335, 'y': 346},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 20,
#     'position': {'x': 333, 'y': 340},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 21,
#     'position': {'x': 351, 'y': 339},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 22,
#     'position': {'x': 331, 'y': 337},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 23,
#     'position': {'x': 304, 'y': 331},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 24,
#     'position': {'x': 340, 'y': 324},
#     'width': 3,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 25,
#     'position': {'x': 345, 'y': 315},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 26,
#     'position': {'x': 355, 'y': 307},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 27,
#     'position': {'x': 345, 'y': 305},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 28,
#     'position': {'x': 310, 'y': 302},
#     'width': 4,
#     'height': 4,
#     'area': 7},
#    {'dot_id': 29,
#     'position': {'x': 511, 'y': 197},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 30,
#     'position': {'x': 302, 'y': 133},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 31,
#     'position': {'x': 333, 'y': 123},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 32,
#     'position': {'x': 294, 'y': 122},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 33,
#     'position': {'x': 316, 'y': 122},
#     'width': 3,
#     'height': 5,
#     'area': 5},
#    {'dot_id': 34,
#     'position': {'x': 295, 'y': 117},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 35,
#     'position': {'x': 290, 'y': 116},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 36,
#     'position': {'x': 310, 'y': 114},
#     'width': 3,
#     'height': 4,
#     'area': 4},
#    {'dot_id': 37,
#     'position': {'x': 301, 'y': 114},
#     'width': 4,
#     'height': 4,
#     'area': 8},
#    {'dot_id': 38,
#     'position': {'x': 307, 'y': 109},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 39,
#     'position': {'x': 288, 'y': 109},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 40,
#     'position': {'x': 342, 'y': 106},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 41,
#     'position': {'x': 328, 'y': 105},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 42,
#     'position': {'x': 286, 'y': 103},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 43,
#     'position': {'x': 275, 'y': 86},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 44,
#     'position': {'x': 311, 'y': 85},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 45,
#     'position': {'x': 318, 'y': 84},
#     'width': 4,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 46,
#     'position': {'x': 269, 'y': 79},
#     'width': 6,
#     'height': 8,
#     'area': 25},
#    {'dot_id': 47,
#     'position': {'x': 261, 'y': 75},
#     'width': 5,
#     'height': 5,
#     'area': 13},
#    {'dot_id': 48,
#     'position': {'x': 289, 'y': 60},
#     'width': 4,
#     'height': 4,
#     'area': 6}]},
#  {'image_name': 'flattened_position_26_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_26_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 185, 'y': 472},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 2,
#     'position': {'x': 253, 'y': 446},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 3,
#     'position': {'x': 262, 'y': 427},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 4,
#     'position': {'x': 64, 'y': 430},
#     'width': 9,
#     'height': 9,
#     'area': 42},
#    {'dot_id': 5,
#     'position': {'x': 97, 'y': 426},
#     'width': 9,
#     'height': 6,
#     'area': 23},
#    {'dot_id': 6,
#     'position': {'x': 232, 'y': 396},
#     'width': 4,
#     'height': 4,
#     'area': 8},
#    {'dot_id': 7,
#     'position': {'x': 95, 'y': 395},
#     'width': 4,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 8,
#     'position': {'x': 209, 'y': 392},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 9,
#     'position': {'x': 369, 'y': 388},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 10,
#     'position': {'x': 386, 'y': 388},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 11,
#     'position': {'x': 387, 'y': 377},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 12,
#     'position': {'x': 372, 'y': 379},
#     'width': 7,
#     'height': 7,
#     'area': 22},
#    {'dot_id': 13,
#     'position': {'x': 398, 'y': 373},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 14,
#     'position': {'x': 228, 'y': 373},
#     'width': 4,
#     'height': 4,
#     'area': 9},
#    {'dot_id': 15,
#     'position': {'x': 393, 'y': 368},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 16,
#     'position': {'x': 201, 'y': 368},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 17,
#     'position': {'x': 416, 'y': 358},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 18,
#     'position': {'x': 358, 'y': 357},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 19,
#     'position': {'x': 397, 'y': 357},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 20,
#     'position': {'x': 393, 'y': 350},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 21,
#     'position': {'x': 384, 'y': 348},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 22,
#     'position': {'x': 367, 'y': 348},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 23,
#     'position': {'x': 382, 'y': 342},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 24,
#     'position': {'x': 378, 'y': 342},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 25,
#     'position': {'x': 401, 'y': 337},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 26,
#     'position': {'x': 370, 'y': 336},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 27,
#     'position': {'x': 392, 'y': 339},
#     'width': 7,
#     'height': 11,
#     'area': 37},
#    {'dot_id': 28,
#     'position': {'x': 382, 'y': 329},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 29,
#     'position': {'x': 217, 'y': 292},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 30,
#     'position': {'x': 347, 'y': 288},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 31,
#     'position': {'x': 355, 'y': 283},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 32,
#     'position': {'x': 363, 'y': 280},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 33,
#     'position': {'x': 350, 'y': 282},
#     'width': 7,
#     'height': 10,
#     'area': 22},
#    {'dot_id': 34,
#     'position': {'x': 344, 'y': 276},
#     'width': 7,
#     'height': 7,
#     'area': 16},
#    {'dot_id': 35,
#     'position': {'x': 352, 'y': 263},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 36,
#     'position': {'x': 358, 'y': 259},
#     'width': 5,
#     'height': 6,
#     'area': 17},
#    {'dot_id': 37,
#     'position': {'x': 347, 'y': 254},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 38,
#     'position': {'x': 366, 'y': 257},
#     'width': 9,
#     'height': 10,
#     'area': 40},
#    {'dot_id': 39,
#     'position': {'x': 356, 'y': 252},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 40,
#     'position': {'x': 369, 'y': 250},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 41,
#     'position': {'x': 336, 'y': 204},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 42,
#     'position': {'x': 354, 'y': 193},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 43,
#     'position': {'x': 348, 'y': 191},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 44,
#     'position': {'x': 363, 'y': 174},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 45,
#     'position': {'x': 314, 'y': 172},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 46,
#     'position': {'x': 320, 'y': 158},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 47,
#     'position': {'x': 316, 'y': 152},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 48,
#     'position': {'x': 318, 'y': 147},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 49,
#     'position': {'x': 302, 'y': 138},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 50,
#     'position': {'x': 338, 'y': 82},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 51,
#     'position': {'x': 325, 'y': 78},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 52,
#     'position': {'x': 318, 'y': 70},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 53,
#     'position': {'x': 353, 'y': 68},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 54,
#     'position': {'x': 352, 'y': 59},
#     'width': 2,
#     'height': 1,
#     'area': 0}]},
#  {'image_name': 'flattened_position_38_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_38_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 60, 'y': 511},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 2,
#     'position': {'x': 289, 'y': 480},
#     'width': 4,
#     'height': 2,
#     'area': 3},
#    {'dot_id': 3,
#     'position': {'x': 323, 'y': 470},
#     'width': 4,
#     'height': 3,
#     'area': 5},
#    {'dot_id': 4,
#     'position': {'x': 341, 'y': 461},
#     'width': 4,
#     'height': 4,
#     'area': 7},
#    {'dot_id': 5,
#     'position': {'x': 349, 'y': 454},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 6,
#     'position': {'x': 497, 'y': 439},
#     'width': 3,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 7,
#     'position': {'x': 486, 'y': 435},
#     'width': 10,
#     'height': 8,
#     'area': 35},
#    {'dot_id': 8,
#     'position': {'x': 496, 'y': 431},
#     'width': 5,
#     'height': 5,
#     'area': 12},
#    {'dot_id': 9,
#     'position': {'x': 484, 'y': 422},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 10,
#     'position': {'x': 476, 'y': 425},
#     'width': 10,
#     'height': 12,
#     'area': 45},
#    {'dot_id': 11,
#     'position': {'x': 496, 'y': 418},
#     'width': 4,
#     'height': 5,
#     'area': 11},
#    {'dot_id': 12,
#     'position': {'x': 487, 'y': 419},
#     'width': 12,
#     'height': 12,
#     'area': 40},
#    {'dot_id': 13,
#     'position': {'x': 53, 'y': 390},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 14,
#     'position': {'x': 274, 'y': 386},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 15,
#     'position': {'x': 42, 'y': 384},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 16,
#     'position': {'x': 6, 'y': 372},
#     'width': 4,
#     'height': 9,
#     'area': 21},
#    {'dot_id': 17,
#     'position': {'x': 22, 'y': 368},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 18,
#     'position': {'x': 124, 'y': 316},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 19,
#     'position': {'x': 99, 'y': 312},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 20,
#     'position': {'x': 145, 'y': 299},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 21,
#     'position': {'x': 344, 'y': 260},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 22,
#     'position': {'x': 383, 'y': 246},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 23,
#     'position': {'x': 478, 'y': 237},
#     'width': 3,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 24,
#     'position': {'x': 470, 'y': 211},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 25,
#     'position': {'x': 470, 'y': 201},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 26,
#     'position': {'x': 270, 'y': 151},
#     'width': 4,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 27,
#     'position': {'x': 230, 'y': 147},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 28,
#     'position': {'x': 256, 'y': 134},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 29,
#     'position': {'x': 252, 'y': 119},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 30,
#     'position': {'x': 446, 'y': 57},
#     'width': 4,
#     'height': 3,
#     'area': 5},
#    {'dot_id': 31,
#     'position': {'x': 461, 'y': 49},
#     'width': 6,
#     'height': 5,
#     'area': 13},
#    {'dot_id': 32,
#     'position': {'x': 432, 'y': 31},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 33,
#     'position': {'x': 431, 'y': 26},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 34,
#     'position': {'x': 171, 'y': 15},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 35,
#     'position': {'x': 164, 'y': 14},
#     'width': 3,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 36,
#     'position': {'x': 447, 'y': 1},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 37,
#     'position': {'x': 170, 'y': 0},
#     'width': 2,
#     'height': 1,
#     'area': 0}]},
#  {'image_name': 'flattened_position_4_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_4_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 154, 'y': 495},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 2,
#     'position': {'x': 136, 'y': 488},
#     'width': 3,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 3,
#     'position': {'x': 143, 'y': 482},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 4,
#     'position': {'x': 365, 'y': 414},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 5,
#     'position': {'x': 365, 'y': 401},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 6,
#     'position': {'x': 344, 'y': 394},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 7,
#     'position': {'x': 373, 'y': 393},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 8,
#     'position': {'x': 337, 'y': 380},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 9,
#     'position': {'x': 279, 'y': 371},
#     'width': 5,
#     'height': 5,
#     'area': 11},
#    {'dot_id': 10,
#     'position': {'x': 382, 'y': 364},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 11,
#     'position': {'x': 302, 'y': 343},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 12,
#     'position': {'x': 99, 'y': 341},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 13,
#     'position': {'x': 85, 'y': 332},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 14,
#     'position': {'x': 104, 'y': 329},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 15,
#     'position': {'x': 95, 'y': 330},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 16,
#     'position': {'x': 105, 'y': 303},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 17,
#     'position': {'x': 291, 'y': 248},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 18,
#     'position': {'x': 289, 'y': 240},
#     'width': 9,
#     'height': 10,
#     'area': 36},
#    {'dot_id': 19,
#     'position': {'x': 256, 'y': 230},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 20,
#     'position': {'x': 298, 'y': 226},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 21,
#     'position': {'x': 250, 'y': 225},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 22,
#     'position': {'x': 280, 'y': 216},
#     'width': 3,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 23,
#     'position': {'x': 300, 'y': 211},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 24,
#     'position': {'x': 282, 'y': 207},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 25,
#     'position': {'x': 263, 'y': 206},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 26,
#     'position': {'x': 258, 'y': 197},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 27,
#     'position': {'x': 261, 'y': 187},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 28,
#     'position': {'x': 57, 'y': 185},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 29,
#     'position': {'x': 269, 'y': 183},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 30,
#     'position': {'x': 64, 'y': 178},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 31,
#     'position': {'x': 34, 'y': 178},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 32,
#     'position': {'x': 47, 'y': 171},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 33,
#     'position': {'x': 71, 'y': 171},
#     'width': 4,
#     'height': 4,
#     'area': 4},
#    {'dot_id': 34,
#     'position': {'x': 52, 'y': 168},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 35,
#     'position': {'x': 85, 'y': 162},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 36,
#     'position': {'x': 58, 'y': 160},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 37,
#     'position': {'x': 457, 'y': 98},
#     'width': 4,
#     'height': 4,
#     'area': 7},
#    {'dot_id': 38,
#     'position': {'x': 434, 'y': 90},
#     'width': 4,
#     'height': 5,
#     'area': 8},
#    {'dot_id': 39,
#     'position': {'x': 452, 'y': 88},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 40,
#     'position': {'x': 406, 'y': 88},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 41,
#     'position': {'x': 441, 'y': 86},
#     'width': 5,
#     'height': 5,
#     'area': 14},
#    {'dot_id': 42,
#     'position': {'x': 416, 'y': 84},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 43,
#     'position': {'x': 424, 'y': 85},
#     'width': 3,
#     'height': 5,
#     'area': 6},
#    {'dot_id': 44,
#     'position': {'x': 319, 'y': 46},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 45,
#     'position': {'x': 323, 'y': 35},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 46,
#     'position': {'x': 328, 'y': 29},
#     'width': 1,
#     'height': 2,
#     'area': 0}]},
#  {'image_name': 'flattened_position_8_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_8_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 458, 'y': 510},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 2,
#     'position': {'x': 452, 'y': 510},
#     'width': 4,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 3,
#     'position': {'x': 463, 'y': 507},
#     'width': 6,
#     'height': 7,
#     'area': 21},
#    {'dot_id': 4,
#     'position': {'x': 464, 'y': 499},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 5,
#     'position': {'x': 473, 'y': 488},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 6,
#     'position': {'x': 469, 'y': 487},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 7,
#     'position': {'x': 435, 'y': 484},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 8,
#     'position': {'x': 475, 'y': 482},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 9,
#     'position': {'x': 466, 'y': 481},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 10,
#     'position': {'x': 202, 'y': 481},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 11,
#     'position': {'x': 461, 'y': 476},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 12,
#     'position': {'x': 480, 'y': 473},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 13,
#     'position': {'x': 241, 'y': 472},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 14,
#     'position': {'x': 479, 'y': 470},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 15,
#     'position': {'x': 453, 'y': 470},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 16,
#     'position': {'x': 204, 'y': 470},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 17,
#     'position': {'x': 247, 'y': 469},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 18,
#     'position': {'x': 214, 'y': 468},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 19,
#     'position': {'x': 469, 'y': 468},
#     'width': 4,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 20,
#     'position': {'x': 435, 'y': 468},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 21,
#     'position': {'x': 421, 'y': 467},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 22,
#     'position': {'x': 460, 'y': 463},
#     'width': 4,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 23,
#     'position': {'x': 235, 'y': 459},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 24,
#     'position': {'x': 439, 'y': 458},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 25,
#     'position': {'x': 240, 'y': 458},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 26,
#     'position': {'x': 246, 'y': 456},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 27,
#     'position': {'x': 228, 'y': 455},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 28,
#     'position': {'x': 163, 'y': 451},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 29,
#     'position': {'x': 221, 'y': 450},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 30,
#     'position': {'x': 188, 'y': 449},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 31,
#     'position': {'x': 206, 'y': 446},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 32,
#     'position': {'x': 440, 'y': 436},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 33,
#     'position': {'x': 236, 'y': 434},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 34,
#     'position': {'x': 199, 'y': 432},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 35,
#     'position': {'x': 78, 'y': 360},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 36,
#     'position': {'x': 3, 'y': 323},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 37,
#     'position': {'x': 173, 'y': 318},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 38,
#     'position': {'x': 134, 'y': 311},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 39,
#     'position': {'x': 114, 'y': 311},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 40,
#     'position': {'x': 180, 'y': 305},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 41,
#     'position': {'x': 138, 'y': 306},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 42,
#     'position': {'x': 156, 'y': 305},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 43,
#     'position': {'x': 16, 'y': 302},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 44,
#     'position': {'x': 13, 'y': 297},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 45,
#     'position': {'x': 161, 'y': 293},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 46,
#     'position': {'x': 169, 'y': 291},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 47,
#     'position': {'x': 12, 'y': 287},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 48,
#     'position': {'x': 8, 'y': 284},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 49,
#     'position': {'x': 150, 'y': 283},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 50,
#     'position': {'x': 13, 'y': 279},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 51,
#     'position': {'x': 10, 'y': 278},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 52,
#     'position': {'x': 175, 'y': 273},
#     'width': 3,
#     'height': 4,
#     'area': 4},
#    {'dot_id': 53,
#     'position': {'x': 367, 'y': 270},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 54,
#     'position': {'x': 160, 'y': 267},
#     'width': 3,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 55,
#     'position': {'x': 8, 'y': 264},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 56,
#     'position': {'x': 185, 'y': 259},
#     'width': 3,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 57,
#     'position': {'x': 400, 'y': 258},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 58,
#     'position': {'x': 396, 'y': 257},
#     'width': 3,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 59,
#     'position': {'x': 377, 'y': 256},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 60,
#     'position': {'x': 357, 'y': 253},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 61,
#     'position': {'x': 361, 'y': 251},
#     'width': 3,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 62,
#     'position': {'x': 367, 'y': 247},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 63,
#     'position': {'x': 97, 'y': 248},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 64,
#     'position': {'x': 107, 'y': 246},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 65,
#     'position': {'x': 358, 'y': 245},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 66,
#     'position': {'x': 379, 'y': 242},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 67,
#     'position': {'x': 373, 'y': 243},
#     'width': 5,
#     'height': 5,
#     'area': 12},
#    {'dot_id': 68,
#     'position': {'x': 94, 'y': 243},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 69,
#     'position': {'x': 344, 'y': 238},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 70,
#     'position': {'x': 398, 'y': 238},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 71,
#     'position': {'x': 97, 'y': 237},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 72,
#     'position': {'x': 368, 'y': 226},
#     'width': 4,
#     'height': 5,
#     'area': 8},
#    {'dot_id': 73,
#     'position': {'x': 334, 'y': 219},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 74,
#     'position': {'x': 104, 'y': 218},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 75,
#     'position': {'x': 82, 'y': 216},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 76,
#     'position': {'x': 90, 'y': 216},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 77,
#     'position': {'x': 109, 'y': 216},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 78,
#     'position': {'x': 348, 'y': 214},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 79,
#     'position': {'x': 102, 'y': 212},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 80,
#     'position': {'x': 104, 'y': 194},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 81,
#     'position': {'x': 426, 'y': 175},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 82,
#     'position': {'x': 452, 'y': 173},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 83,
#     'position': {'x': 412, 'y': 169},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 84,
#     'position': {'x': 444, 'y': 164},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 85,
#     'position': {'x': 452, 'y': 161},
#     'width': 3,
#     'height': 4,
#     'area': 4},
#    {'dot_id': 86,
#     'position': {'x': 9, 'y': 160},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 87,
#     'position': {'x': 414, 'y': 153},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 88,
#     'position': {'x': 309, 'y': 147},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 89,
#     'position': {'x': 441, 'y': 144},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 90,
#     'position': {'x': 408, 'y': 138},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 91,
#     'position': {'x': 455, 'y': 134},
#     'width': 4,
#     'height': 5,
#     'area': 9},
#    {'dot_id': 92,
#     'position': {'x': 2, 'y': 130},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 93,
#     'position': {'x': 345, 'y': 90},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 94,
#     'position': {'x': 510, 'y': 69},
#     'width': 3,
#     'height': 4,
#     'area': 3},
#    {'dot_id': 95,
#     'position': {'x': 365, 'y': 59},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 96,
#     'position': {'x': 340, 'y': 57},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 97,
#     'position': {'x': 354, 'y': 56},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 98,
#     'position': {'x': 368, 'y': 51},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 99,
#     'position': {'x': 312, 'y': 50},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 100,
#     'position': {'x': 312, 'y': 46},
#     'width': 3,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 101,
#     'position': {'x': 326, 'y': 40},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 102,
#     'position': {'x': 300, 'y': 39},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 103,
#     'position': {'x': 323, 'y': 37},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 104,
#     'position': {'x': 331, 'y': 33},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 105,
#     'position': {'x': 301, 'y': 33},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 106,
#     'position': {'x': 360, 'y': 30},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 107,
#     'position': {'x': 342, 'y': 28},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 108,
#     'position': {'x': 352, 'y': 26},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 109,
#     'position': {'x': 355, 'y': 22},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 110,
#     'position': {'x': 309, 'y': 21},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 111,
#     'position': {'x': 361, 'y': 22},
#     'width': 3,
#     'height': 4,
#     'area': 2},
#    {'dot_id': 112,
#     'position': {'x': 337, 'y': 16},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 113,
#     'position': {'x': 323, 'y': 16},
#     'width': 4,
#     'height': 5,
#     'area': 9},
#    {'dot_id': 114,
#     'position': {'x': 320, 'y': 5},
#     'width': 2,
#     'height': 1,
#     'area': 0}]},
#  {'image_name': 'flattened_position_12_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_12_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 394, 'y': 421},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 2,
#     'position': {'x': 382, 'y': 421},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 3,
#     'position': {'x': 404, 'y': 416},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 4,
#     'position': {'x': 421, 'y': 416},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 5,
#     'position': {'x': 405, 'y': 410},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 6,
#     'position': {'x': 435, 'y': 408},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 7,
#     'position': {'x': 411, 'y': 408},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 8,
#     'position': {'x': 389, 'y': 394},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 9,
#     'position': {'x': 201, 'y': 391},
#     'width': 4,
#     'height': 3,
#     'area': 5},
#    {'dot_id': 10,
#     'position': {'x': 144, 'y': 372},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 11,
#     'position': {'x': 198, 'y': 370},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 12,
#     'position': {'x': 202, 'y': 369},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 13,
#     'position': {'x': 157, 'y': 362},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 14,
#     'position': {'x': 177, 'y': 357},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 15,
#     'position': {'x': 166, 'y': 359},
#     'width': 5,
#     'height': 6,
#     'area': 14},
#    {'dot_id': 16,
#     'position': {'x': 128, 'y': 350},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 17,
#     'position': {'x': 208, 'y': 350},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 18,
#     'position': {'x': 13, 'y': 348},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 19,
#     'position': {'x': 182, 'y': 339},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 20,
#     'position': {'x': 195, 'y': 336},
#     'width': 4,
#     'height': 5,
#     'area': 10},
#    {'dot_id': 21,
#     'position': {'x': 202, 'y': 331},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 22,
#     'position': {'x': 199, 'y': 331},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 23,
#     'position': {'x': 166, 'y': 326},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 24,
#     'position': {'x': 4, 'y': 215},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 25,
#     'position': {'x': 16, 'y': 193},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 26,
#     'position': {'x': 6, 'y': 187},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 27,
#     'position': {'x': 220, 'y': 138},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 28,
#     'position': {'x': 195, 'y': 131},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 29,
#     'position': {'x': 374, 'y': 123},
#     'width': 8,
#     'height': 7,
#     'area': 30},
#    {'dot_id': 30,
#     'position': {'x': 198, 'y': 118},
#     'width': 6,
#     'height': 7,
#     'area': 25},
#    {'dot_id': 31,
#     'position': {'x': 396, 'y': 111},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 32,
#     'position': {'x': 381, 'y': 111},
#     'width': 4,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 33,
#     'position': {'x': 370, 'y': 113},
#     'width': 6,
#     'height': 6,
#     'area': 18},
#    {'dot_id': 34,
#     'position': {'x': 209, 'y': 108},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 35,
#     'position': {'x': 421, 'y': 103},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 36,
#     'position': {'x': 222, 'y': 100},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 37,
#     'position': {'x': 183, 'y': 100},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 38,
#     'position': {'x': 211, 'y': 92},
#     'width': 5,
#     'height': 4,
#     'area': 9},
#    {'dot_id': 39,
#     'position': {'x': 415, 'y': 89},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 40,
#     'position': {'x': 176, 'y': 89},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 41,
#     'position': {'x': 213, 'y': 86},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 42,
#     'position': {'x': 170, 'y': 83},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 43,
#     'position': {'x': 182, 'y': 81},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 44,
#     'position': {'x': 211, 'y': 78},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 45,
#     'position': {'x': 187, 'y': 79},
#     'width': 4,
#     'height': 3,
#     'area': 5},
#    {'dot_id': 46,
#     'position': {'x': 396, 'y': 76},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 47,
#     'position': {'x': 414, 'y': 74},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 48,
#     'position': {'x': 206, 'y': 75},
#     'width': 7,
#     'height': 7,
#     'area': 14},
#    {'dot_id': 49,
#     'position': {'x': 431, 'y': 71},
#     'width': 4,
# ...
#    {'dot_id': 19,
#     'position': {'x': 408, 'y': 371},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 20,
#     'position': {'x': 461, 'y': 368},
#     'width': 5,
#     'height': 4,
#     'area': 8},
#    {'dot_id': 21,
#     'position': {'x': 195, 'y': 365},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 22,
#     'position': {'x': 485, 'y': 347},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 23,
#     'position': {'x': 430, 'y': 346},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 24,
#     'position': {'x': 417, 'y': 338},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 25,
#     'position': {'x': 353, 'y': 268},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 26,
#     'position': {'x': 183, 'y': 262},
#     'width': 3,
#     'height': 4,
#     'area': 4},
#    {'dot_id': 27,
#     'position': {'x': 175, 'y': 258},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 28,
#     'position': {'x': 165, 'y': 255},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 29,
#     'position': {'x': 200, 'y': 254},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 30,
#     'position': {'x': 13, 'y': 235},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 31,
#     'position': {'x': 213, 'y': 234},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 32,
#     'position': {'x': 196, 'y': 233},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 33,
#     'position': {'x': 360, 'y': 223},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 34,
#     'position': {'x': 368, 'y': 217},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 35,
#     'position': {'x': 368, 'y': 201},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 36,
#     'position': {'x': 373, 'y': 192},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 37,
#     'position': {'x': 365, 'y': 191},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 38,
#     'position': {'x': 348, 'y': 190},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 39,
#     'position': {'x': 373, 'y': 188},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 40,
#     'position': {'x': 67, 'y': 188},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 41,
#     'position': {'x': 57, 'y': 184},
#     'width': 4,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 42,
#     'position': {'x': 366, 'y': 179},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 43,
#     'position': {'x': 374, 'y': 168},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 44,
#     'position': {'x': 81, 'y': 168},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 45,
#     'position': {'x': 11, 'y': 169},
#     'width': 4,
#     'height': 4,
#     'area': 7},
#    {'dot_id': 46,
#     'position': {'x': 74, 'y': 154},
#     'width': 4,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 47,
#     'position': {'x': 31, 'y': 136},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 48,
#     'position': {'x': 390, 'y': 134},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 49,
#     'position': {'x': 68, 'y': 135},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 50,
#     'position': {'x': 248, 'y': 112},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 51,
#     'position': {'x': 231, 'y': 86},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 52,
#     'position': {'x': 237, 'y': 64},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 53,
#     'position': {'x': 253, 'y': 60},
#     'width': 6,
#     'height': 6,
#     'area': 22},
#    {'dot_id': 54,
#     'position': {'x': 240, 'y': 47},
#     'width': 5,
#     'height': 5,
#     'area': 14},
#    {'dot_id': 55,
#     'position': {'x': 286, 'y': 36},
#     'width': 1,
#     'height': 1,
#     'area': 0}]},
#  {'image_name': 'flattened_position_23_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_23_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 312, 'y': 507},
#     'width': 2,
#     'height': 4,
#     'area': 2},
#    {'dot_id': 2,
#     'position': {'x': 22, 'y': 496},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 3,
#     'position': {'x': 63, 'y': 388},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 4,
#     'position': {'x': 60, 'y': 377},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 5,
#     'position': {'x': 60, 'y': 363},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 6,
#     'position': {'x': 32, 'y': 361},
#     'width': 3,
#     'height': 4,
#     'area': 4},
#    {'dot_id': 7,
#     'position': {'x': 24, 'y': 361},
#     'width': 4,
#     'height': 5,
#     'area': 9},
#    {'dot_id': 8,
#     'position': {'x': 77, 'y': 354},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 9,
#     'position': {'x': 447, 'y': 351},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 10,
#     'position': {'x': 445, 'y': 340},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 11,
#     'position': {'x': 93, 'y': 340},
#     'width': 5,
#     'height': 5,
#     'area': 8},
#    {'dot_id': 12,
#     'position': {'x': 436, 'y': 339},
#     'width': 10,
#     'height': 6,
#     'area': 29},
#    {'dot_id': 13,
#     'position': {'x': 450, 'y': 335},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 14,
#     'position': {'x': 453, 'y': 331},
#     'width': 5,
#     'height': 5,
#     'area': 10},
#    {'dot_id': 15,
#     'position': {'x': 414, 'y': 321},
#     'width': 5,
#     'height': 7,
#     'area': 22},
#    {'dot_id': 16,
#     'position': {'x': 440, 'y': 318},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 17,
#     'position': {'x': 451, 'y': 315},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 18,
#     'position': {'x': 429, 'y': 316},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 19,
#     'position': {'x': 426, 'y': 315},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 20,
#     'position': {'x': 454, 'y': 314},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 21,
#     'position': {'x': 447, 'y': 307},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 22,
#     'position': {'x': 462, 'y': 302},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 23,
#     'position': {'x': 441, 'y': 303},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 24,
#     'position': {'x': 420, 'y': 295},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 25,
#     'position': {'x': 436, 'y': 294},
#     'width': 5,
#     'height': 5,
#     'area': 12},
#    {'dot_id': 26,
#     'position': {'x': 449, 'y': 288},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 27,
#     'position': {'x': 445, 'y': 283},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 28,
#     'position': {'x': 316, 'y': 279},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 29,
#     'position': {'x': 319, 'y': 271},
#     'width': 4,
#     'height': 4,
#     'area': 8},
#    {'dot_id': 30,
#     'position': {'x': 301, 'y': 270},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 31,
#     'position': {'x': 291, 'y': 255},
#     'width': 5,
#     'height': 5,
#     'area': 15},
#    {'dot_id': 32,
#     'position': {'x': 317, 'y': 250},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 33,
#     'position': {'x': 318, 'y': 244},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 34,
#     'position': {'x': 328, 'y': 199},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 35,
#     'position': {'x': 114, 'y': 196},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 36,
#     'position': {'x': 345, 'y': 192},
#     'width': 6,
#     'height': 5,
#     'area': 14},
#    {'dot_id': 37,
#     'position': {'x': 319, 'y': 188},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 38,
#     'position': {'x': 350, 'y': 181},
#     'width': 4,
#     'height': 5,
#     'area': 11},
#    {'dot_id': 39,
#     'position': {'x': 360, 'y': 172},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 40,
#     'position': {'x': 105, 'y': 170},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 41,
#     'position': {'x': 107, 'y': 162},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 42,
#     'position': {'x': 345, 'y': 155},
#     'width': 2,
#     'height': 4,
#     'area': 3},
#    {'dot_id': 43,
#     'position': {'x': 121, 'y': 153},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 44,
#     'position': {'x': 242, 'y': 151},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 45,
#     'position': {'x': 226, 'y': 149},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 46,
#     'position': {'x': 230, 'y': 136},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 47,
#     'position': {'x': 233, 'y': 130},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 48,
#     'position': {'x': 206, 'y': 124},
#     'width': 3,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 49,
#     'position': {'x': 235, 'y': 117},
#     'width': 1,
#     'height': 2,
#     'area': 0}]},
#  {'image_name': 'flattened_position_31_C1',
#   'label': 'arsenic',
#   'nucleus_mask': '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/binary_mask_nucleus_high_arsenic/flattened_position_31_C1_mask.tiff',
#   'dots': [{'dot_id': 1,
#     'position': {'x': 412, 'y': 505},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 2,
#     'position': {'x': 437, 'y': 491},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 3,
#     'position': {'x': 411, 'y': 486},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 4,
#     'position': {'x': 407, 'y': 478},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 5,
#     'position': {'x': 90, 'y': 463},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 6,
#     'position': {'x': 396, 'y': 462},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 7,
#     'position': {'x': 430, 'y': 456},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 8,
#     'position': {'x': 70, 'y': 453},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 9,
#     'position': {'x': 404, 'y': 451},
#     'width': 3,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 10,
#     'position': {'x': 89, 'y': 447},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 11,
#     'position': {'x': 401, 'y': 447},
#     'width': 4,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 12,
#     'position': {'x': 73, 'y': 445},
#     'width': 3,
#     'height': 2,
#     'area': 2},
#    {'dot_id': 13,
#     'position': {'x': 425, 'y': 442},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 14,
#     'position': {'x': 407, 'y': 443},
#     'width': 4,
#     'height': 4,
#     'area': 6},
#    {'dot_id': 15,
#     'position': {'x': 93, 'y': 433},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 16,
#     'position': {'x': 64, 'y': 432},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 17,
#     'position': {'x': 405, 'y': 413},
#     'width': 4,
#     'height': 3,
#     'area': 4},
#    {'dot_id': 18,
#     'position': {'x': 82, 'y': 325},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 19,
#     'position': {'x': 86, 'y': 318},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 20,
#     'position': {'x': 78, 'y': 320},
#     'width': 5,
#     'height': 5,
#     'area': 8},
#    {'dot_id': 21,
#     'position': {'x': 375, 'y': 318},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 22,
#     'position': {'x': 96, 'y': 316},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 23,
#     'position': {'x': 16, 'y': 312},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 24,
#     'position': {'x': 29, 'y': 308},
#     'width': 3,
#     'height': 4,
#     'area': 5},
#    {'dot_id': 25,
#     'position': {'x': 376, 'y': 282},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 26,
#     'position': {'x': 337, 'y': 278},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 27,
#     'position': {'x': 414, 'y': 272},
#     'width': 4,
#     'height': 4,
#     'area': 8},
#    {'dot_id': 28,
#     'position': {'x': 387, 'y': 267},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 29,
#     'position': {'x': 374, 'y': 263},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 30,
#     'position': {'x': 367, 'y': 249},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 31,
#     'position': {'x': 348, 'y': 247},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 32,
#     'position': {'x': 334, 'y': 248},
#     'width': 1,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 33,
#     'position': {'x': 128, 'y': 146},
#     'width': 4,
#     'height': 4,
#     'area': 8},
#    {'dot_id': 34,
#     'position': {'x': 278, 'y': 141},
#     'width': 4,
#     'height': 5,
#     'area': 10},
#    {'dot_id': 35,
#     'position': {'x': 274, 'y': 136},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 36,
#     'position': {'x': 232, 'y': 133},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 37,
#     'position': {'x': 255, 'y': 128},
#     'width': 2,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 38,
#     'position': {'x': 129, 'y': 124},
#     'width': 4,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 39,
#     'position': {'x': 115, 'y': 116},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 40,
#     'position': {'x': 253, 'y': 114},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 41,
#     'position': {'x': 136, 'y': 111},
#     'width': 3,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 42,
#     'position': {'x': 108, 'y': 105},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 43,
#     'position': {'x': 123, 'y': 104},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 44,
#     'position': {'x': 147, 'y': 101},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 45,
#     'position': {'x': 126, 'y': 100},
#     'width': 3,
#     'height': 3,
#     'area': 3},
#    {'dot_id': 46,
#     'position': {'x': 140, 'y': 97},
#     'width': 2,
#     'height': 3,
#     'area': 1},
#    {'dot_id': 47,
#     'position': {'x': 122, 'y': 96},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 48,
#     'position': {'x': 163, 'y': 92},
#     'width': 2,
#     'height': 2,
#     'area': 1},
#    {'dot_id': 49,
#     'position': {'x': 138, 'y': 88},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 50,
#     'position': {'x': 142, 'y': 83},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 51,
#     'position': {'x': 181, 'y': 76},
#     'width': 4,
#     'height': 5,
#     'area': 9},
#    {'dot_id': 52,
#     'position': {'x': 163, 'y': 75},
#     'width': 7,
#     'height': 3,
#     'area': 6},
#    {'dot_id': 53,
#     'position': {'x': 152, 'y': 70},
#     'width': 3,
#     'height': 3,
#     'area': 2},
#    {'dot_id': 54,
#     'position': {'x': 109, 'y': 60},
#     'width': 2,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 55,
#     'position': {'x': 427, 'y': 57},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 56,
#     'position': {'x': 155, 'y': 53},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 57,
#     'position': {'x': 437, 'y': 44},
#     'width': 3,
#     'height': 4,
#     'area': 4},
#    {'dot_id': 58,
#     'position': {'x': 439, 'y': 38},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 59,
#     'position': {'x': 158, 'y': 29},
#     'width': 1,
#     'height': 1,
#     'area': 0},
#    {'dot_id': 60,
#     'position': {'x': 462, 'y': 23},
#     'width': 2,
#     'height': 2,
#     'area': 0},
#    {'dot_id': 61,
#     'position': {'x': 430, 'y': 6},
#     'width': 4,
#     'height': 4,
#     'area': 8}]}]
