# %% [markdown]
# # Preprocessing and Counting PML Bodies

# %%
import json
import numpy as np
from scipy.spatial import distance
from skimage import io  # Importing image loading library
import os
import cv2
import pandas as pd

# %%
json_path = '/Users/pallavisingh/Library/CloudStorage/OneDrive-SharedLibraries-DalhousieUniversity/Priyadharshini Sridharan - Images from Dellaire Lab/input/combined_annotations.json'

# %%
# Load JSON file
with open(json_path) as f:
    data = json.load(f)

# Initialize lists to store results for each image
inside_counts = []
outside_counts = []
mean_distances = []
variance_distances = []
inside_densities = []
outside_densities = []

# %%
df = pd.DataFrame(data)
df
# Out:
#                    image_name        label  \
# 0    flattened_position_10_C1  not arsenic
# 1     flattened_position_6_C1  not arsenic
# 2     flattened_position_4_C1  not arsenic
# 3   flattened_position_6-1_C1  not arsenic
# 4   flattened_position_7-1_C1  not arsenic
# ..                        ...          ...
# 75   flattened_position_19_C1      arsenic
# 76   flattened_position_15_C1      arsenic
# 77   flattened_position_40_C1      arsenic
# 78   flattened_position_23_C1      arsenic
# 79   flattened_position_31_C1      arsenic
#
#                                          nucleus_mask  \
# 0   /Users/pallavisingh/Documents/test/binary_mask...
# 1   /Users/pallavisingh/Documents/test/binary_mask...
# 2   /Users/pallavisingh/Documents/test/binary_mask...
# 3   /Users/pallavisingh/Documents/test/binary_mask...
# 4   /Users/pallavisingh/Documents/test/binary_mask...
# ..                                                ...
# 75  /Users/pallavisingh/Documents/test/binary_mask...
# 76  /Users/pallavisingh/Documents/test/binary_mask...
# 77  /Users/pallavisingh/Documents/test/binary_mask...
# 78  /Users/pallavisingh/Documents/test/binary_mask...
# 79  /Users/pallavisingh/Documents/test/binary_mask...
#
#                                                  dots
# 0   [{'dot_id': 1, 'position': {'x': 469, 'y': 511...
# 1   [{'dot_id': 1, 'position': {'x': 223, 'y': 511...
# 2   [{'dot_id': 1, 'position': {'x': 193, 'y': 472...
# 3   [{'dot_id': 1, 'position': {'x': 504, 'y': 510...
# 4   [{'dot_id': 1, 'position': {'x': 64, 'y': 504}...
# ..                                                ...
# 75  [{'dot_id': 1, 'position': {'x': 441, 'y': 416...
# 76  [{'dot_id': 1, 'position': {'x': 394, 'y': 441...
# 77  [{'dot_id': 1, 'position': {'x': 301, 'y': 457...
# 78  [{'dot_id': 1, 'position': {'x': 312, 'y': 507...
# 79  [{'dot_id': 1, 'position': {'x': 412, 'y': 505...
#
# [80 rows x 4 columns]

# %%
# Process each image entry in the JSON data
for entry in data:
    # Load the nucleus mask image as a numpy array using OpenCV
    x = str(entry['nucleus_mask'].strip())  # Ensure no leading/trailing spaces
    nucleus_mask = cv2.imread(entry['nucleus_mask'], cv2.IMREAD_GRAYSCALE)  # Read the image in grayscale

    if nucleus_mask is None:
        print(f"Failed to load image: {x}")
        continue

    # Ensure the mask is binary (0s and 1s)
    _, nucleus_mask = cv2.threshold(nucleus_mask, 127, 1, cv2.THRESH_BINARY)  # Convert to binary mask

    pml_bodies = entry['dots']  # Access the dots (PML body coordinates) from JSON
    image_height, image_width = nucleus_mask.shape

    # Count PML bodies inside and outside the nucleus
    inside_count = 0
    outside_count = 0

    for dot in pml_bodies:
        x, y = dot['position']['x'], dot['position']['y']  # Get coordinates from dot entry
        if dot['location'].strip() == 'inside_nucleus':  # Inside nucleus
            inside_count += 1
        else:  # Outside nucleus
            outside_count += 1

    # Store counts
    inside_counts.append(inside_count)
    outside_counts.append(outside_count)

    # Calculate distances if needed
    # Assuming you want to calculate distances here (commented out in your original code)
    distances = []  # You might want to calculate distances based on your requirement

    # Calculate mean and variance of distances (if applicable)
    if distances:
        mean_distances.append(np.mean(distances))
        variance_distances.append(np.var(distances))
    else:
        mean_distances.append(0)
        variance_distances.append(0)

    # Calculate densities (dots per unit area)
    nucleus_area = np.sum(nucleus_mask)  # This will count the number of pixels in the nucleus
    non_nucleus_area = image_height * image_width - nucleus_area

    inside_density = inside_count / nucleus_area if nucleus_area > 0 else 0
    outside_density = outside_count / non_nucleus_area if non_nucleus_area > 0 else 0

    inside_densities.append(inside_density)
    outside_densities.append(outside_density)

# Print summary statistics
for i, entry in enumerate(data):
    print(f"Image {i + 1} - {entry['image_name']}:")
    print("PML bodies inside nucleus:", inside_counts[i])
    print("PML bodies outside nucleus:", outside_counts[i])
    print("Average distance to nucleus edge:", mean_distances[i])
    print("Variance of distances to nucleus edge:", variance_distances[i])
    print("Density of PML bodies inside nucleus:", inside_densities[i])
    print("Density of PML bodies outside nucleus:", outside_densities[i])
    print("\n")
# Out:
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_10_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_6_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_4_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_6-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_7-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_8_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_12_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_20-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_14-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_15-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_1-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_20_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_19-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_18-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_16_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_13-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_12-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_2_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_18_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_14_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_17-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_16-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_11_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_7_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_5-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_4-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_5_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_9_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_13_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_17_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_3_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_10-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_19_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_11-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_8-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_9-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_15_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_2-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_3-1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_10_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_6_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_34_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_26_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_38_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_4_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_8_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_12_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_24_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_28_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_36_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_32_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_20_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_16_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_22_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_30_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_2_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_18_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_14_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_35_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_39_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_27_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_11_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_7_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_25_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_37_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_29_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_5_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_9_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_13_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_17_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_1_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_33_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_21_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_3_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_19_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_15_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_40_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_23_C1_mask.tiff
# Failed to load image: /Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_31_C1_mask.tiff
# Image 1 - flattened_position_10_C1:
# [ WARN:0@458.812] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_10_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_6_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_4_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_6-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_7-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_8_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_12_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_20-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_14-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_15-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_1-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_20_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_19-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_18-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.813] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_16_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_13-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_12-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_2_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_18_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_14_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_17-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_16-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_11_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_7_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_5-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_4-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_5_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_9_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_13_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 57
#      55 for i, entry in enumerate(data):
#      56     print(f"Image {i + 1} - {entry['image_name']}:")
# ---> 57     print("PML bodies inside nucleus:", inside_counts[i])
#      58     print("PML bodies outside nucleus:", outside_counts[i])
#      59     print("Average distance to nucleus edge:", mean_distances[i])
#
# IndexError: list index out of range
# @458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_17_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_3_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_10-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_19_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_11-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_8-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_9-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_15_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_2-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_non_arsenic/flattened_position_3-1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_10_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_6_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_34_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_26_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_38_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_4_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_8_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_12_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_24_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_28_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_36_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_32_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.814] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_20_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_16_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_22_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_30_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_2_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_18_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_14_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_35_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_39_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_27_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_11_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_7_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_25_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_37_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_29_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_5_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_9_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_13_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_17_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_1_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_33_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_21_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_3_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_19_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_15_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_40_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_23_C1_mask.tiff'): can't open/read file: check file path/integrity
# [ WARN:0@458.815] global loadsave.cpp:248 findDecoder imread_('/Users/pallavisingh/Documents/test/binary_mask_nucleus_high_arsenic/binary_mask_nucleus_high_arsenic/flattened_position_31_C1_mask.tiff'): can't open/read file: check file path/integrity
